# %%
from googletrans import Translator
import pandas as pd
import numpy as np
import requests
import time

# %%
translator = Translator()

# %%
#testing translator with some copied codes
text1 = '''
A Római Birodalom (latinul Imperium Romanum) az ókori Róma által létrehozott 
államalakulat volt a Földközi-tenger medencéjében
'''

text2 = '''
Vysoké Tatry sú najvyššie pohorie na Slovensku a v Poľsku a sú zároveň jediným 
horstvom v týchto štátoch s alpským charakterom. 
'''

translator = Translator()

dt1 = translator.detect(text1)
print(dt1)

dt2 = translator.detect(text2)
print(dt2)
# Out:
# Detected(lang=hu, confidence=None)
# Detected(lang=sk, confidence=None)

# %%
#testing translator with some copied codes

translator.translate('Vamos traduzir um texto de Português para o Inglês').text
# Out:
# "Let's translate a Portuguese text into English"

# %%
translator.translate('是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道').text
# Out:
# 'It is a one -stop channel for you to obtain business thinking and key information of cryptocurrencies.'

# %%
#loading data to df for testing
df = pd.read_csv('video_details.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                       descriptions  \
# 0           0  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 1           1  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 2           2  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 3           3  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 4           4  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
#
#                                               titles  view_counts  \
# 0     幣圈熊市又一波？幣圈另類巨人Silvergate頂唔順 ｜又關FTX事｜廣告Rstaking         1116
# 1                    幣圈熊市罪魁禍首 - 佢令到Bitcoin跌了50,000美金         1228
# 2       FTX前員工大爆料: 超誇張福利｜SBF被野生捕獲｜FTX無經驗都可以做高層｜用不完的錢          672
# 3  [Airbnb] 連續12年蝕錢，上市市值即過千億｜全世界最大的房地產公司｜「共享經濟」市場...         1064
# 4           [Celsius破產] 手法比FTX更高章｜客戶既錢就係我既錢 ｜魔鬼就在細節中          796
#
#                 channel_ids         publish_dates  \
# 0  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-03-10T15:51:27Z
# 1  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-03-01T04:13:54Z
# 2  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-18T04:00:16Z
# 3  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-14T06:00:08Z
# 4  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-11T11:30:06Z
#
#                                                 tags  \
# 0  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 1  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 2  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 3  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 4  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
#
#                                           thumbnails
# 0  {'url': 'https://i.ytimg.com/vi/SrrUfSnxA-k/de...
# 1  {'url': 'https://i.ytimg.com/vi/50pyDCuaLM8/de...
# 2  {'url': 'https://i.ytimg.com/vi/oDj_nSJGNNs/de...
# 3  {'url': 'https://i.ytimg.com/vi/SQMY0NnmEuk/de...
# 4  {'url': 'https://i.ytimg.com/vi/O-OeytUFyhY/de...

# %%
#trying translator on 1 description
test_text = df.loc[0, 'descriptions']
translator.translate(test_text).text
# Out:
# 'Blockz Finance is a one-stop channel for your business thinking and key information of cryptocurrencies 2023-03-11\n\nAdvertising in this episode: rstishing\nhttps://rstaking.com/?c83=561028\n\nSilvergate top?Another round of bear market?\n"I wish you peace in the chaos"\n\n\n⏱ ⏱ ⏱ chapter\nStart at 00:00\n00:41 Silvergate Bank background and importance\n03:24 Advertising RSTAKING\n05:33 Silvergate happened at home?Why is the reason?\n08:19 The United States suppress Crypto\'s regional development of the currency circle\n\n\n的 You may be interested in the playlist\n\nSto stable currency will also be decoupled?Disassemble the two types of stable currencies\nhttps://youtu.be/dw-zvdb0my\n\n热 Crypto hot words, close to the currency circle\nhttps://bit.ly/3ib5vgh\n\n， 🔴 🔴 🔴 Raiders, dismantle the market trend with you\nhttps://bit.ly/3LSX2YH\n\n学 Blockchain novice teaching, must -see for getting started\nhttps://bit.ly/30cxvu8\n\nRemember to CLSS, Comment, Like, Share and "Subscribe" Channel\n\nSocial platforms:\nInstagram: https://www.instagram.com/alfred.blockz/\nFacebook: https://www.facebook.com/alfred.blockz\n\n\nMarketing partner:\nACESBLOCK: http://acesblock.com/'

# %%
#creating a smaller df to test function for translating whole columns
df2 = df.head(10).copy()
df2
# Out:
#    Unnamed: 0                                       descriptions  \
# 0           0  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 1           1  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 2           2  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 3           3  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 4           4  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 5           5  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 6           6  Blockz Academy 是您獲取加密貨幣世界所有新聞報導的一站式頻道 2022-12-...
# 7           7  Blockz Academy 是您獲取加密貨幣世界所有新聞報導的一站式頻道 2022-12-...
# 8           8  Blockz Academy 是您獲取加密貨幣世界所有新聞報導的一站式頻道 2022-12-...
# 9           9  Blockz Academy 是您獲取加密貨幣世界所有新聞報導的一站式頻道 2022-12-...
#
#                                               titles  view_counts  \
# 0     幣圈熊市又一波？幣圈另類巨人Silvergate頂唔順 ｜又關FTX事｜廣告Rstaking         1116
# 1                    幣圈熊市罪魁禍首 - 佢令到Bitcoin跌了50,000美金         1228
# 2       FTX前員工大爆料: 超誇張福利｜SBF被野生捕獲｜FTX無經驗都可以做高層｜用不完的錢          672
# 3  [Airbnb] 連續12年蝕錢，上市市值即過千億｜全世界最大的房地產公司｜「共享經濟」市場...         1064
# 4           [Celsius破產] 手法比FTX更高章｜客戶既錢就係我既錢 ｜魔鬼就在細節中          796
# 5  [DCG帝國崩塌] 600,000粒比特幣會流入市場？關 Terra Luna FTX 咩事...         1095
# 6         [WEB3一分鐘] Ep3: 點解會出現Web3? 咩係Web1.0 Web2.0？          625
# 7  [全世界都係Scam系列] Binance 幣安都出現擠提？！會唔會出現死亡螺旋？｜六大門派...          686
# 8                       [WEB3一分鐘] Ep2: 各地政府點睇Web3.0?          660
# 9           [聖誕大解放] FTX事件前世今生｜SBF天造之才 走進迷陣？事件最新動態係點？         1187
#
#                 channel_ids         publish_dates  \
# 0  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-03-10T15:51:27Z
# 1  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-03-01T04:13:54Z
# 2  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-18T04:00:16Z
# 3  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-14T06:00:08Z
# 4  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-11T11:30:06Z
# 5  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-06T06:30:11Z
# 6  UCcAyw5OwGXDMJfFx3q9U4XQ  2022-12-31T06:00:07Z
# 7  UCcAyw5OwGXDMJfFx3q9U4XQ  2022-12-28T07:00:19Z
# 8  UCcAyw5OwGXDMJfFx3q9U4XQ  2022-12-27T07:00:01Z
# 9  UCcAyw5OwGXDMJfFx3q9U4XQ  2022-12-25T07:00:02Z
#
#                                                 tags  \
# 0  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 1  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 2  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 3  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 4  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 5  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 6  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 7  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 8  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 9  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
#
#                                           thumbnails
# 0  {'url': 'https://i.ytimg.com/vi/SrrUfSnxA-k/de...
# 1  {'url': 'https://i.ytimg.com/vi/50pyDCuaLM8/de...
# 2  {'url': 'https://i.ytimg.com/vi/oDj_nSJGNNs/de...
# 3  {'url': 'https://i.ytimg.com/vi/SQMY0NnmEuk/de...
# 4  {'url': 'https://i.ytimg.com/vi/O-OeytUFyhY/de...
# 5  {'url': 'https://i.ytimg.com/vi/UqkzcatQFhE/de...
# 6  {'url': 'https://i.ytimg.com/vi/MHGfOYnQqXw/de...
# 7  {'url': 'https://i.ytimg.com/vi/nnvIvV7RMV0/de...
# 8  {'url': 'https://i.ytimg.com/vi/9S6mglCGmVg/de...
# 9  {'url': 'https://i.ytimg.com/vi/3CyBMPFKJNg/de...

# %%
#applying translation to all titles
df2['translated titles'] = df2['titles'].apply(lambda x: (time.sleep(3), translator.translate(x, src='zh-TW', dest='en').text))

df2.head()
# Out:
#    Unnamed: 0                                       descriptions  \
# 0           0  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 1           1  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 2           2  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 3           3  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 4           4  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
#
#                                               titles  view_counts  \
# 0     幣圈熊市又一波？幣圈另類巨人Silvergate頂唔順 ｜又關FTX事｜廣告Rstaking         1116
# 1                    幣圈熊市罪魁禍首 - 佢令到Bitcoin跌了50,000美金         1228
# 2       FTX前員工大爆料: 超誇張福利｜SBF被野生捕獲｜FTX無經驗都可以做高層｜用不完的錢          672
# 3  [Airbnb] 連續12年蝕錢，上市市值即過千億｜全世界最大的房地產公司｜「共享經濟」市場...         1064
# 4           [Celsius破產] 手法比FTX更高章｜客戶既錢就係我既錢 ｜魔鬼就在細節中          796
#
#                 channel_ids         publish_dates  \
# 0  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-03-10T15:51:27Z
# 1  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-03-01T04:13:54Z
# 2  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-18T04:00:16Z
# 3  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-14T06:00:08Z
# 4  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-11T11:30:06Z
#
#                                                 tags  \
# 0  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 1  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 2  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 3  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 4  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
#
#                                           thumbnails  \
# 0  {'url': 'https://i.ytimg.com/vi/SrrUfSnxA-k/de...
# 1  {'url': 'https://i.ytimg.com/vi/50pyDCuaLM8/de...
# 2  {'url': 'https://i.ytimg.com/vi/oDj_nSJGNNs/de...
# 3  {'url': 'https://i.ytimg.com/vi/SQMY0NnmEuk/de...
# 4  {'url': 'https://i.ytimg.com/vi/O-OeytUFyhY/de...
#
#                                    translated titles
# 0  (None, There is another wave of bear markets i...
# 1  (None, The culprit in the currency circle -has...
# 2  (None, Pre -FTX employee broke the news: Super...
# 3  (None, [Airbnb] Extracting money for 12 consec...
# 4  (None, [Celsius bankruptcy] Higher chapter tha...

# %%
#creating a translate function

def translate(text):
    time.sleep(1)
    translator = Translator()
    translation = translator.translate(text, src='zh-TW', dest='en')
    return translation.text

# %%
#testing
text = '是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道'
translate(text)
# Out:
# 'It is a one -stop channel for you to obtain business thinking and key information of cryptocurrencies.'

# %%
#reload df2 and test on titles column only
df2['translated titles'] = df2['titles'].apply(translate)

# %%
df2.head()
# Out:
#    Unnamed: 0                                       descriptions  \
# 0           0  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 1           1  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 2           2  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 3           3  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 4           4  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
#
#                                               titles  view_counts  \
# 0     幣圈熊市又一波？幣圈另類巨人Silvergate頂唔順 ｜又關FTX事｜廣告Rstaking         1116
# 1                    幣圈熊市罪魁禍首 - 佢令到Bitcoin跌了50,000美金         1228
# 2       FTX前員工大爆料: 超誇張福利｜SBF被野生捕獲｜FTX無經驗都可以做高層｜用不完的錢          672
# 3  [Airbnb] 連續12年蝕錢，上市市值即過千億｜全世界最大的房地產公司｜「共享經濟」市場...         1064
# 4           [Celsius破產] 手法比FTX更高章｜客戶既錢就係我既錢 ｜魔鬼就在細節中          796
#
#                 channel_ids         publish_dates  \
# 0  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-03-10T15:51:27Z
# 1  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-03-01T04:13:54Z
# 2  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-18T04:00:16Z
# 3  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-14T06:00:08Z
# 4  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-11T11:30:06Z
#
#                                                 tags  \
# 0  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 1  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 2  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 3  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 4  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
#
#                                           thumbnails  \
# 0  {'url': 'https://i.ytimg.com/vi/SrrUfSnxA-k/de...
# 1  {'url': 'https://i.ytimg.com/vi/50pyDCuaLM8/de...
# 2  {'url': 'https://i.ytimg.com/vi/oDj_nSJGNNs/de...
# 3  {'url': 'https://i.ytimg.com/vi/SQMY0NnmEuk/de...
# 4  {'url': 'https://i.ytimg.com/vi/O-OeytUFyhY/de...
#
#                                    translated titles
# 0  There is another wave of bear markets in the c...
# 1  The culprit in the currency circle -has ordere...
# 2  Pre -FTX employee broke the news: Super exagge...
# 3  [Airbnb] Extracting money for 12 consecutive y...
# 4  [Celsius bankruptcy] Higher chapter than FTX ｜...

# %%
#testing on more columns 
columns_to_translate = ['tags', 'descriptions']

for column in columns_to_translate:
    df2[f'translated {column}'] = df2[column].apply(translate)

# %%
df2.head()
# Out:
#    Unnamed: 0                                       descriptions  \
# 0           0  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 1           1  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 2           2  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 3           3  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 4           4  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
#
#                                               titles  view_counts  \
# 0     幣圈熊市又一波？幣圈另類巨人Silvergate頂唔順 ｜又關FTX事｜廣告Rstaking         1116
# 1                    幣圈熊市罪魁禍首 - 佢令到Bitcoin跌了50,000美金         1228
# 2       FTX前員工大爆料: 超誇張福利｜SBF被野生捕獲｜FTX無經驗都可以做高層｜用不完的錢          672
# 3  [Airbnb] 連續12年蝕錢，上市市值即過千億｜全世界最大的房地產公司｜「共享經濟」市場...         1064
# 4           [Celsius破產] 手法比FTX更高章｜客戶既錢就係我既錢 ｜魔鬼就在細節中          796
#
#                 channel_ids         publish_dates  \
# 0  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-03-10T15:51:27Z
# 1  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-03-01T04:13:54Z
# 2  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-18T04:00:16Z
# 3  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-14T06:00:08Z
# 4  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-11T11:30:06Z
#
#                                                 tags  \
# 0  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 1  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 2  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 3  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 4  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
#
#                                           thumbnails  \
# 0  {'url': 'https://i.ytimg.com/vi/SrrUfSnxA-k/de...
# 1  {'url': 'https://i.ytimg.com/vi/50pyDCuaLM8/de...
# 2  {'url': 'https://i.ytimg.com/vi/oDj_nSJGNNs/de...
# 3  {'url': 'https://i.ytimg.com/vi/SQMY0NnmEuk/de...
# 4  {'url': 'https://i.ytimg.com/vi/O-OeytUFyhY/de...
#
#                                    translated titles  \
# 0  There is another wave of bear markets in the c...
# 1  The culprit in the currency circle -has ordere...
# 2  Pre -FTX employee broke the news: Super exagge...
# 3  [Airbnb] Extracting money for 12 consecutive y...
# 4  [Celsius bankruptcy] Higher chapter than FTX ｜...
#
#                                      translated tags  \
# 0  ['Investment', 'to get rich', 'make money', 'r...
# 1  ['Investment', 'to get rich', 'make money', 'r...
# 2  ['Investment', 'to get rich', 'make money', 'r...
# 3  ['Investment', 'to get rich', 'make money', 'r...
# 4  ['Investment', 'to get rich', 'make money', 'r...
#
#                              translated descriptions
# 0  Blockz Finance is a one-stop channel for your ...
# 1  Blockz Finance is a one-stop channel for your ...
# 2  Blockz Finance is a one-stop channel for your ...
# 3  Blockz Finance is a one-stop channel for your ...
# 4  Blockz Finance is a one-stop channel for your ...

# %%
df2.to_csv('translation test.csv')

# %%
#testing on full df
columns_to_translate = ['tags', 'descriptions','titles']
start_time = time.time() 
for column in columns_to_translate:
    df[f'translated {column}'] = df[column].apply(translate)

end_time = time.time() 
total_time = end_time - start_time 
data_df.head()
# Out:
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# Cell In[13], line 5
#       3 start_time = time.time()
#       4 for column in columns_to_translate:
# ----> 5     df[f'translated {column}'] = df[column].apply(translate)
#       7 end_time = time.time()
#       8 total_time = end_time - start_time
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
#    4756         convert_dtype=convert_dtype,
#    4757         by_row=by_row,
#    4758         args=args,
#    4759         kwargs=kwargs,
# -> 4760     ).apply()
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\apply.py:1207, in SeriesApply.apply(self)
#    1204     return self.apply_compat()
#    1206 # self.func is Callable
# -> 1207 return self.apply_standard()
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\apply.py:1287, in SeriesApply.apply_standard(self)
#    1281 # row-wise access
#    1282 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1283 # we need to give `na_action="ignore"` for categorical data.
#    1284 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1285 #  Categorical (GH51645).
#    1286 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1287 mapped = obj._map_values(
#    1288     mapper=curried, na_action=action, convert=self.convert_dtype
#    1289 )
#    1291 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1292     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1293     #  See also GH#25959 regarding EA support
#    1294     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2920, in pandas._libs.lib.map_infer()
#
# Cell In[11], line 6, in translate(text)
#       4 time.sleep(1)
#       5 translator = Translator()
# ----> 6 translation = translator.translate(text, src='zh-TW', dest='en')
#       7 return translation.text
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\googletrans\client.py:194, in Translator.translate(self, text, dest, src)
#     191         raise ValueError('invalid destination language')
#     193 origin = text
# --> 194 data, response = self._translate(text, dest, src)
#     196 token_found = False
#     197 square_bracket_counts = [0, 0]
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\googletrans\client.py:120, in Translator._translate(self, text, dest, src)
#     109 data = {
#     110     'f.req': self._build_rpc_request(text, dest, src),
#     111 }
#     112 params = {
#     113     'rpcids': RPC_ID,
#     114     'bl': 'boq_translate-webserver_20201207.13_p0',
#    (...)
#     118     'rt': 'c',
#     119 }
# --> 120 r = self.client.post(url, params=params, data=data)
#     122 if r.status_code != 200 and self.raise_Exception:
#     123     raise Exception('Unexpected status code "{}" from {}'.format(
#     124         r.status_code, self.service_urls))
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\httpx\_client.py:824, in Client.post(self, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     810 def post(
#     811     self,
#     812     url: URLTypes,
#    (...)
#     822     timeout: typing.Union[TimeoutTypes, UnsetType] = UNSET,
#     823 ) -> Response:
# --> 824     return self.request(
#     825         "POST",
#     826         url,
#     827         data=data,
#     828         files=files,
#     829         json=json,
#     830         params=params,
#     831         headers=headers,
#     832         cookies=cookies,
#     833         auth=auth,
#     834         allow_redirects=allow_redirects,
#     835         timeout=timeout,
#     836     )
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\httpx\_client.py:600, in Client.request(self, method, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     575 def request(
#     576     self,
#     577     method: str,
#    (...)
#     588     timeout: typing.Union[TimeoutTypes, UnsetType] = UNSET,
#     589 ) -> Response:
#     590     request = self.build_request(
#     591         method=method,
#     592         url=url,
#    (...)
#     598         cookies=cookies,
#     599     )
# --> 600     return self.send(
#     601         request, auth=auth, allow_redirects=allow_redirects, timeout=timeout,
#     602     )
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\httpx\_client.py:620, in Client.send(self, request, stream, auth, allow_redirects, timeout)
#     616 timeout = self.timeout if isinstance(timeout, UnsetType) else Timeout(timeout)
#     618 auth = self.build_auth(request, auth)
# --> 620 response = self.send_handling_redirects(
#     621     request, auth=auth, timeout=timeout, allow_redirects=allow_redirects,
#     622 )
#     624 if not stream:
#     625     try:
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\httpx\_client.py:647, in Client.send_handling_redirects(self, request, auth, timeout, allow_redirects, history)
#     644 if len(history) > self.max_redirects:
#     645     raise TooManyRedirects()
# --> 647 response = self.send_handling_auth(
#     648     request, auth=auth, timeout=timeout, history=history
#     649 )
#     650 response.history = list(history)
#     652 if not response.is_redirect:
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\httpx\_client.py:684, in Client.send_handling_auth(self, request, history, auth, timeout)
#     682 request = next(auth_flow)
#     683 while True:
# --> 684     response = self.send_single_request(request, timeout)
#     685     if auth.requires_response_body:
#     686         response.read()
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\httpx\_client.py:714, in Client.send_single_request(self, request, timeout)
#     705 transport = self.transport_for_url(request.url)
#     707 try:
#     708     (
#     709         http_version,
#     710         status_code,
#     711         reason_phrase,
#     712         headers,
#     713         stream,
# --> 714     ) = transport.request(
#     715         request.method.encode(),
#     716         request.url.raw,
#     717         headers=request.headers.raw,
#     718         stream=request.stream,
#     719         timeout=timeout.as_dict(),
#     720     )
#     721 except HTTPError as exc:
#     722     # Add the original request to any HTTPError unless
#     723     # there'a already a request attached in the case of
#     724     # a ProxyError.
#     725     if exc._request is None:
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:152, in SyncConnectionPool.request(self, method, url, headers, stream, timeout)
#     149         logger.trace("reuse connection=%r", connection)
#     151 try:
# --> 152     response = connection.request(
#     153         method, url, headers=headers, stream=stream, timeout=timeout
#     154     )
#     155 except NewConnectionRequired:
#     156     connection = None
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\httpcore\_sync\connection.py:78, in SyncHTTPConnection.request(self, method, url, headers, stream, timeout)
#      74 assert self.connection is not None
#      75 logger.trace(
#      76     "connection.request method=%r url=%r headers=%r", method, url, headers
#      77 )
# ---> 78 return self.connection.request(method, url, headers, stream, timeout)
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\httpcore\_sync\http2.py:118, in SyncHTTP2Connection.request(self, method, url, headers, stream, timeout)
#     116     self.streams[stream_id] = h2_stream
#     117     self.events[stream_id] = []
# --> 118     return h2_stream.request(method, url, headers, stream, timeout)
#     119 except Exception:
#     120     self.max_streams_semaphore.release()
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\httpcore\_sync\http2.py:292, in SyncHTTP2Stream.request(self, method, url, headers, stream, timeout)
#     289     self.send_body(stream, timeout)
#     291 # Receive the response.
# --> 292 status_code, headers = self.receive_response(timeout)
#     293 reason_phrase = get_reason_phrase(status_code)
#     294 stream = SyncByteStream(
#     295     iterator=self.body_iter(timeout), close_func=self._response_closed
#     296 )
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\httpcore\_sync\http2.py:344, in SyncHTTP2Stream.receive_response(self, timeout)
#     340 """
#     341 Read the response status and headers from the network.
#     342 """
#     343 while True:
# --> 344     event = self.connection.wait_for_event(self.stream_id, timeout)
#     345     if isinstance(event, h2.events.ResponseReceived):
#     346         break
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\httpcore\_sync\http2.py:197, in SyncHTTP2Connection.wait_for_event(self, stream_id, timeout)
#     195 with self.read_lock:
#     196     while not self.events[stream_id]:
# --> 197         self.receive_events(timeout)
#     198 return self.events[stream_id].pop(0)
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\httpcore\_sync\http2.py:204, in SyncHTTP2Connection.receive_events(self, timeout)
#     200 def receive_events(self, timeout: TimeoutDict) -> None:
#     201     """
#     202     Read some data from the network, and update the H2 state.
#     203     """
# --> 204     data = self.socket.read(self.READ_NUM_BYTES, timeout)
#     205     events = self.h2_state.receive_data(data)
#     206     for event in events:
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\httpcore\_backends\sync.py:60, in SyncSocketStream.read(self, n, timeout)
#      57 exc_map = {socket.timeout: ReadTimeout, socket.error: ReadError}
#      59 with self.read_lock:
# ---> 60     with map_exceptions(exc_map):
#      61         self.sock.settimeout(read_timeout)
#      62         return self.sock.recv(n)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     153     value = typ()
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#     160     return exc is not value
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\httpcore\_exceptions.py:12, in map_exceptions(map)
#      10 for from_exc, to_exc in map.items():
#      11     if isinstance(exc, from_exc):
# ---> 12         raise to_exc(exc) from None
#      13 raise
#
# ReadTimeout: The read operation timed out

# %%
#create df2 of 20 entires for testing agian
df2=df.head(20).copy()
df2.head()
# Out:
#    Unnamed: 0                                       descriptions  \
# 0           0  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 1           1  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 2           2  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 3           3  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
# 4           4  Blockz Finance 是您獲取商業思維、加密貨幣世界重點資訊的一站式頻道 2023-...
#
#                                               titles  view_counts  \
# 0     幣圈熊市又一波？幣圈另類巨人Silvergate頂唔順 ｜又關FTX事｜廣告Rstaking         1116
# 1                    幣圈熊市罪魁禍首 - 佢令到Bitcoin跌了50,000美金         1228
# 2       FTX前員工大爆料: 超誇張福利｜SBF被野生捕獲｜FTX無經驗都可以做高層｜用不完的錢          672
# 3  [Airbnb] 連續12年蝕錢，上市市值即過千億｜全世界最大的房地產公司｜「共享經濟」市場...         1064
# 4           [Celsius破產] 手法比FTX更高章｜客戶既錢就係我既錢 ｜魔鬼就在細節中          796
#
#                 channel_ids         publish_dates  \
# 0  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-03-10T15:51:27Z
# 1  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-03-01T04:13:54Z
# 2  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-18T04:00:16Z
# 3  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-14T06:00:08Z
# 4  UCcAyw5OwGXDMJfFx3q9U4XQ  2023-01-11T11:30:06Z
#
#                                                 tags  \
# 0  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 1  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 2  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 3  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
# 4  ['投資', '致富', '賺錢', '有錢人', '區塊鏈', '比特幣', 'bitco...
#
#                                           thumbnails
# 0  {'url': 'https://i.ytimg.com/vi/SrrUfSnxA-k/de...
# 1  {'url': 'https://i.ytimg.com/vi/50pyDCuaLM8/de...
# 2  {'url': 'https://i.ytimg.com/vi/oDj_nSJGNNs/de...
# 3  {'url': 'https://i.ytimg.com/vi/SQMY0NnmEuk/de...
# 4  {'url': 'https://i.ytimg.com/vi/O-OeytUFyhY/de...

# %%
#testing time of processing
columns_to_translate = ['tags', 'descriptions','titles']
start_time = time.time() 

for column in columns_to_translate:
    df2[f'translated {column}'] = df2[column].apply(translate)

end_time = time.time() 
total_time = end_time - start_time 

df2.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 6
#       3 start_time = time.time()
#       5 for column in columns_to_translate:
# ----> 6     df2[f'translated {column}'] = df2[column].apply(translate)
#       8 end_time = time.time()
#       9 total_time = end_time - start_time
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
#    4756         convert_dtype=convert_dtype,
#    4757         by_row=by_row,
#    4758         args=args,
#    4759         kwargs=kwargs,
# -> 4760     ).apply()
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\apply.py:1207, in SeriesApply.apply(self)
#    1204     return self.apply_compat()
#    1206 # self.func is Callable
# -> 1207 return self.apply_standard()
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\apply.py:1287, in SeriesApply.apply_standard(self)
#    1281 # row-wise access
#    1282 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1283 # we need to give `na_action="ignore"` for categorical data.
#    1284 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1285 #  Categorical (GH51645).
#    1286 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1287 mapped = obj._map_values(
#    1288     mapper=curried, na_action=action, convert=self.convert_dtype
#    1289 )
#    1291 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1292     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1293     #  See also GH#25959 regarding EA support
#    1294     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2920, in pandas._libs.lib.map_infer()
#
# Cell In[11], line 6, in translate(text)
#       4 time.sleep(1)
#       5 translator = Translator()
# ----> 6 translation = translator.translate(text, src='zh-TW', dest='en')
#       7 return translation.text
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\googletrans\client.py:194, in Translator.translate(self, text, dest, src)
#     191         raise ValueError('invalid destination language')
#     193 origin = text
# --> 194 data, response = self._translate(text, dest, src)
#     196 token_found = False
#     197 square_bracket_counts = [0, 0]
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\googletrans\client.py:122, in Translator._translate(self, text, dest, src)
#     112 params = {
#     113     'rpcids': RPC_ID,
#     114     'bl': 'boq_translate-webserver_20201207.13_p0',
#    (...)
#     118     'rt': 'c',
#     119 }
#     120 r = self.client.post(url, params=params, data=data)
# --> 122 if r.status_code != 200 and self.raise_Exception:
#     123     raise Exception('Unexpected status code "{}" from {}'.format(
#     124         r.status_code, self.service_urls))
#     126 return r.text, r
#
# AttributeError: 'Translator' object has no attribute 'raise_Exception'

# %%
#time for translating 20 entries
print(total_time)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 #time for translating 20 entries
# ----> 2 print(total_time)
#
# NameError: name 'total_time' is not defined

# %%
#total size of DF
len(df)
# Out:
# 7085

# %%
#theortical total time for translation. 
88*7085/60/60
# Out:
# 173.1888888888889

# %%
#trying a batch

columns_to_translate = ['tags', 'descriptions','titles']

#translate a batch of text
def translate_batch(batch):
    return batch.map(translate)

batch_size = 100
total_rows = len(df)

start_time = time.time()

#terate in batches
for i in range(0, total_rows, batch_size):
    batch = df.loc[i:i+batch_size-1, columns_to_translate]
    
#translate the batch
    translated_batch = translate_batch(batch)
    
#put values back in df
    for column in columns_to_translate:
        translated_column = f'translated {column}'
        df.loc[i:i+batch_size-1, translated_column] = translated_batch[column]
    
#sleep break    
    time.sleep(1)  


end_time = time.time()
total_time = end_time - start_time


    
# Display the resulting DataFrame
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 19
#      16     batch = df.loc[i:i+batch_size-1, columns_to_translate]
#      18 #translate the batch
# ---> 19     translated_batch = translate_batch(batch)
#      21 #put values back in df
#      22     for column in columns_to_translate:
#
# Cell In[32], line 7, in translate_batch(batch)
#       6 def translate_batch(batch):
# ----> 7     return batch.map(translate)
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\frame.py:10120, in DataFrame.map(self, func, na_action, **kwargs)
#   10117 def infer(x):
#   10118     return x._map_values(func, na_action=na_action)
# > 10120 return self.apply(infer).__finalize__(self, "map")
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\frame.py:10034, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10022 from pandas.core.apply import frame_apply
#   10024 op = frame_apply(
#   10025     self,
#   10026     func=func,
#    (...)
#   10032     kwargs=kwargs,
#   10033 )
# > 10034 return op.apply().__finalize__(self, method="apply")
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\frame.py:10118, in DataFrame.map.<locals>.infer(x)
#   10117 def infer(x):
# > 10118     return x._map_values(func, na_action=na_action)
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2920, in pandas._libs.lib.map_infer()
#
# Cell In[11], line 6, in translate(text)
#       4 time.sleep(1)
#       5 translator = Translator()
# ----> 6 translation = translator.translate(text, src='zh-TW', dest='en')
#       7 return translation.text
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\googletrans\client.py:194, in Translator.translate(self, text, dest, src)
#     191         raise ValueError('invalid destination language')
#     193 origin = text
# --> 194 data, response = self._translate(text, dest, src)
#     196 token_found = False
#     197 square_bracket_counts = [0, 0]
#
# File ~\Documents\Xccelerate\Asia Web3 Project\venv\Lib\site-packages\googletrans\client.py:122, in Translator._translate(self, text, dest, src)
#     112 params = {
#     113     'rpcids': RPC_ID,
#     114     'bl': 'boq_translate-webserver_20201207.13_p0',
#    (...)
#     118     'rt': 'c',
#     119 }
#     120 r = self.client.post(url, params=params, data=data)
# --> 122 if r.status_code != 200 and self.raise_Exception:
#     123     raise Exception('Unexpected status code "{}" from {}'.format(
#     124         r.status_code, self.service_urls))
#     126 return r.text, r
#
# AttributeError: 'Translator' object has no attribute 'raise_Exception'
